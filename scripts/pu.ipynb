# %%
#!pip3 install pandas
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tb3_0 = pd.read_csv('/home/sweksha/ros_ws/src/swarm_aggregation/scripts/processed_codes/data/1689851948_right/tb3_1.csv')
tb3_1 = pd.read_csv('/home/sweksha/ros_ws/src/swarm_aggregation/scripts/processed_codes/data/1689851948_right/tb3_3.csv')
tb3_2 = pd.read_csv('/home/sweksha/ros_ws/src/swarm_aggregation/scripts/processed_codes/data/1689851948_right/tb3_4.csv')
tb3_3 = pd.read_csv('/home/sweksha/ros_ws/src/swarm_aggregation/scripts/processed_codes/data/1689851948_right/tb3_6.csv')
tb3_4 = pd.read_csv('/home/sweksha/ros_ws/src/swarm_aggregation/scripts/processed_codes/data/1689851948_right/tb3_7.csv')
tb3_5 = pd.read_csv('/home/sweksha/ros_ws/src/swarm_aggregation/scripts/processed_codes/data/1689851948_right/tb3_8.csv')

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(tb3_0["time"].to_numpy(),tb3_0[" x"].to_numpy())
ax.plot(tb3_1["time"].to_numpy(),tb3_1[" x"].to_numpy())
ax.plot(tb3_2["time"].to_numpy(),tb3_2[" x"].to_numpy())
ax.plot(tb3_3["time"].to_numpy(),tb3_3[" x"].to_numpy())
ax.plot(tb3_4["time"].to_numpy(),tb3_4[" x"].to_numpy())
ax.plot(tb3_5["time"].to_numpy(),tb3_5[" x"].to_numpy())
ax.set_ylabel("x-coordinate")
ax.set_xlabel("time in seconds")
ax.legend(['bot_0','bot_1','bot_2','bot_3','bot_4','bot_5'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 fig, ax = plt.subplots(figsize=(15,10))
# ----> 2 ax.plot(tb3_0["time"],tb3_0[" x"])
#       3 ax.plot(tb3_1["time"],tb3_1[" x"])
#       4 ax.plot(tb3_2["time"],tb3_2[" x"])
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:1665, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1434 """
#    1435 Plot y versus x as lines and/or markers.
#    1436
#    (...)
#    1662 (``'green'``) or hex strings (``'#008000'``).
#    1663 """
#    1664 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666 for line in lines:
#    1667     self.add_line(line)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:225, in _process_plot_var_args.__call__(self, *args, **kwargs)
#     223     this += args[0],
#     224     args = args[1:]
# --> 225 yield from self._plot_args(this, kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:386, in _process_plot_var_args._plot_args(self, tup, kwargs)
#     383         kw[k] = v
#     385 if len(tup) == 2:
# --> 386     x = _check_1d(tup[0])
#     387     y = _check_1d(tup[-1])
#     388 else:
#
# File /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402, in _check_1d(x)
#    1400 else:
#    1401     try:
# -> 1402         ndim = x[:, None].ndim
#    1403         # work around https://github.com/pandas-dev/pandas/issues/27775
#    1404         # which mean the shape is not as expected. That this ever worked
#    1405         # was an unintentional quirk of pandas the above line will raise
#    1406         # an exception in the future.
#    1407         if ndim < 2:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1033, in Series.__getitem__(self, key)
#    1030     key = np.asarray(key, dtype=bool)
#    1031     return self._get_values(key)
# -> 1033 return self._get_with(key)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1048, in Series._get_with(self, key)
#    1043     raise TypeError(
#    1044         "Indexing a Series with DataFrame is not "
#    1045         "supported, use the appropriate DataFrame column"
#    1046     )
#    1047 elif isinstance(key, tuple):
# -> 1048     return self._get_values_tuple(key)
#    1050 elif not is_list_like(key):
#    1051     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1052     return self.loc[key]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1082, in Series._get_values_tuple(self, key)
#    1077 if com.any_none(*key):
#    1078     # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1079     #  see tests.series.timeseries.test_mpl_compat_hack
#    1080     # the asarray is needed to avoid returning a 2D DatetimeArray
#    1081     result = np.asarray(self._values[key])
# -> 1082     disallow_ndim_indexing(result)
#    1083     return result
#    1085 if not isinstance(self.index, MultiIndex):
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexers/utils.py:343, in disallow_ndim_indexing(result)
#     335 """
#     336 Helper function to disallow multi-dimensional indexing on 1D Series/Index.
#     337
#    (...)
#     340 in GH#30588.
#     341 """
#     342 if np.ndim(result) > 1:
# --> 343     raise ValueError(
#     344         "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     345         "supported. Convert to a numpy array before indexing instead."
#     346     )
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(tb3_0["time"],tb3_0["y"])
ax.plot(tb3_1["time"],tb3_1["y"])
ax.plot(tb3_2["time"],tb3_2["y"])
ax.plot(tb3_3["time"],tb3_3["y"])
ax.plot(tb3_4["time"],tb3_4["y"])
ax.plot(tb3_5["time"],tb3_5["y"])
ax.set_ylabel("y-coordinate")
ax.set_xlabel("time in seconds")
ax.legend(['bot_0','bot_1','bot_2','bot_3','bot_4','bot_5'])

# %%
import numpy as np
from math import inf,isinf
obs = []
ranges = [inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 1.3439146280288696, 1.3351765871047974, 1.3461582660675049, 1.332892656326294, 1.3451396226882935, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 0.9606524705886841, 0.9416261315345764, 0.9316730499267578, 0.942786693572998, 0.9434742331504822, 0.9556254148483276, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf]

pairs = []
for i in range(len(ranges)):
    if not isinf(ranges[i]):
        pairs.append([i,ranges[i]])
pairs = np.array(pairs)
print(pairs)
n = 5  # Number of lists

result = [[] for _ in range(n)]  # Create n empty lists

for item in pairs:
    i = item[0]
    if i > 5:
        result[(i - 6) % n].append(item)

print(result)
# Out:
# [[ 19.           1.34391463]
#  [ 20.           1.33517659]
#  [ 21.           1.34615827]
#  [ 22.           1.33289266]
#  [ 23.           1.34513962]
#  [246.           0.96065247]
#  [247.           0.94162613]
#  [248.           0.93167305]
#  [249.           0.94278669]
#  [250.           0.94347423]
#  [251.           0.95562541]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 19
#      17     i = item[0]
#      18     if i > 5:
# ---> 19         result[(i - 6) % n].append(item)
#      21 print(result)
#
# TypeError: list indices must be integers or slices, not numpy.float64

# %%
import numpy as np
from math import inf,isinf, cos, sin, sqrt, atan2
from geometry_msgs.msg import Point, Twist, Pose2D
def split_list(input_list):
    sublists = []
    sublist = []
    prev_degree = None

    for item in input_list:
        degree, _ = item

        if prev_degree is None or degree - prev_degree <= 3:
            sublist.append(item)
        else:
            sublists.append(sublist)
            sublist = [item]
        prev_degree = degree

    sublists.append(sublist)
    return sublists
obs = []
ranges = [inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 1.3439146280288696, 1.3351765871047974, 1.3461582660675049, 1.332892656326294, 1.3451396226882935, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, 0.9606524705886841, 0.9416261315345764, 0.9316730499267578, 0.942786693572998, 0.9434742331504822, 0.9556254148483276, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf]

pairs = []
for i in range(len(ranges)):
    if not isinf(ranges[i]):
        pairs.append([i,ranges[i]])
# pairs = np.array(pairs)
# print(pairs)

cones = split_list(pairs)
# print(np.array(cones[1])[:,1])
print(cones)

for i in cones:
    angle = np.mean(np.array(i)[:,0])
    distance = np.mean(np.array(i)[:,1])
    if distance < 3 and (angle < 60 or angle > 300):
        obs_x = distance*cos(angle)
        obs_y = distance*sin(angle)
        # print(obs)
        obs.append(Pose2D(obs_x,obs_y,angle))
print(obs,"obs")
print(type(obs))
disij = []
delij = []
x = 2
y = 3
yaw = 20
odom = Pose2D(x,y,yaw)

for obs_element in obs:
    x_diff = obs_element.x - x
    y_diff = obs_element.y - y
    
    dist = sqrt(x_diff**2 + y_diff**2)
    ang = atan2(y_diff, x_diff)
    
    disij.append(dist)
    delij.append(ang)

print(disij)
print(delij)
# Out:
# [[[19, 1.3439146280288696], [20, 1.3351765871047974], [21, 1.3461582660675049], [22, 1.332892656326294], [23, 1.3451396226882935]], [[246, 0.9606524705886841], [247, 0.9416261315345764], [248, 0.9316730499267578], [249, 0.942786693572998], [250, 0.9434742331504822], [251, 0.9556254148483276]]]
# [x: -0.7343167119195618
# y: 1.1216676962760828
# theta: 21.0] obs
# <class 'list'>
# [3.3173212271794545]
# [-2.5396805084985923]

# %% [markdown]
# self.odom = Pose2D(self.x,self.y,self.yaw)
# print(self.odom.x)

# %%
odom = Pose2D(x,y,yaw)
print(odom.theta)
# Out:
# 20

# %%
for i in cones:
    angle = np.mean(np.array(i)[:,0])
    distance = np.mean(np.array(i)[:,1])    
    obs_x = distance*cos(angle)
    obs_y = distance*sin(angle)
    # print(obs)
    obs.append([Pose2D(obs_x,obs_y,angle)])
print(obs,"obs")


disij = []
delij = []
x = 2
y = 3
yaw = 20
odom = Pose2D(x,y,yaw)

for obs_element in obs:
    x_diff = obs_element[0] - x
    y_diff = obs_element[1] - y
    
    dist = sqrt(x_diff**2 + y_diff**2)
    ang = atan2(y_diff, x_diff)
    
    disij.append(dist)
    delij.append(ang)
# Out:
# [[x: -0.7343167119195618
# y: 1.1216676962760828
# theta: 21.0], [x: -0.7343167119195618
# y: 1.1216676962760828
# theta: 21.0], [x: -0.8996676163832548
# y: -0.29234071688541663
# theta: 248.5], [x: -0.7343167119195618
# y: 1.1216676962760828
# theta: 21.0], [x: -0.8996676163832548
# y: -0.29234071688541663
# theta: 248.5], [x: -0.7343167119195618
# y: 1.1216676962760828
# theta: 21.0], [x: -0.8996676163832548
# y: -0.29234071688541663
# theta: 248.5]] obs
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 19
#      16 odom = Pose2D(x,y,yaw)
#      18 for obs_element in obs:
# ---> 19     x_diff = obs_element[0] - x
#      20     y_diff = obs_element[1] - y
#      22     dist = sqrt(x_diff**2 + y_diff**2)
#
# TypeError: unsupported operand type(s) for -: 'Pose2D' and 'int'

# %%
def split_list(input_list):
    sublists = []
    sublist = []
    prev_num = None

    for num in input_list:
        if prev_num is None or num - prev_num <= 3:
            sublist.append(num)
        else:
            sublists.append(sublist)
            sublist = [num]
        prev_num = num

    sublists.append(sublist)
    return sublists


# Example usage
input_list1 = [19, 20, 21, 22, 23, 24, 246, 247, 248, 249, 250]
output1 = split_list(input_list1)
print(output1)

input_list2 = [19, 20, 21, 22, 23, 24, 50, 51, 52, 53, 54, 55, 246, 247, 248, 249, 250]
output2 = split_list(input_list2)
print(output2)
# Out:
# [[19, 20, 21, 22, 23, 24], [246, 247, 248, 249, 250]]
# [[19, 20, 21, 22, 23, 24], [50, 51, 52, 53, 54, 55], [246, 247, 248, 249, 250]]

# %%
from collections import deque
a = deque(maxlen=2)
a.append(1)
a.append(2)
print(a)
a.append(3)
print(a[-1],a[-2])
# Out:
# deque([1, 2], maxlen=2)
# 3 2

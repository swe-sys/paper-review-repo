# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tb3_0 = pd.read_csv('/home/swe/ros_ws/src/swarm_aggregation/scripts/tb3_0.csv')
tb3_1 = pd.read_csv('/home/swe/ros_ws/src/swarm_aggregation/scripts/tb3_1.csv')
tb3_2 = pd.read_csv('/home/swe/ros_ws/src/swarm_aggregation/scripts/tb3_2.csv')
tb3_3 = pd.read_csv('/home/swe/ros_ws/src/swarm_aggregation/scripts/tb3_3.csv')
tb3_4 = pd.read_csv('/home/swe/ros_ws/src/swarm_aggregation/scripts/tb3_4.csv')
tb3_5 = pd.read_csv('/home/swe/ros_ws/src/swarm_aggregation/scripts/tb3_5.csv')

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(tb3_0["time"],tb3_0["x"])
ax.plot(tb3_1["time"],tb3_1["x"])
ax.plot(tb3_2["time"],tb3_2["x"])
ax.plot(tb3_3["time"],tb3_3["x"])
ax.plot(tb3_4["time"],tb3_4["x"])
ax.plot(tb3_5["time"],tb3_5["x"])
ax.set_ylabel("x-coordinate")
ax.set_xlabel("time in seconds")
ax.legend(['bot_0','bot_1','bot_2','bot_3','bot_4','bot_5'])

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(tb3_0["time"],tb3_0["y"])
ax.plot(tb3_1["time"],tb3_1["y"])
ax.plot(tb3_2["time"],tb3_2["y"])
ax.plot(tb3_3["time"],tb3_3["y"])
ax.plot(tb3_4["time"],tb3_4["y"])
ax.plot(tb3_5["time"],tb3_5["y"])
ax.set_ylabel("y-coordinate")
ax.set_xlabel("time in seconds")
ax.legend(['bot_0','bot_1','bot_2','bot_3','bot_4','bot_5'])

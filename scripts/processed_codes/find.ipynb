# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import transforms
import os , glob , sys
import moviepy ,cv2
files = glob.glob("./data/1689845489_right/*csv")
files.sort()
print(files)
turtles = [pd.read_csv(f'{i}') for i in files]
# for i in turtles:
#     plt.plot(i.iloc[-1][3],i.iloc[-1][4],'o')
#     plt.xlim([-2.69,2.75])
#     plt.ylim([-2.5,2.74])
# plt.show()
path = ('./Two_per')
video = cv2.VideoCapture('./data/1689845489_right/GH010941_1689845587412.mp4')
fps = video.get(cv2.CAP_PROP_FPS)
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
time_stamp = video.get(cv2.CAP_PROP_POS_MSEC)
# duration = int(video.get(cv2.CAP_PROP_dur))
video.set(cv2.CAP_PROP_POS_FRAMES, length-1)
ret, frame = video.read()
print(frame.shape)
plt.imshow(cv2.rotate(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB),cv2.ROTATE_90_COUNTERCLOCKWISE))
fig, ax = plt.subplots()
col = ['w','#FF00FF','#afeba4','k','#ff8614','#756758','y']
legend = [name.split('/')[-1].split('.')[0] for name in files]
# tr = transforms.Affine2D().rotate_deg(90)
fig.set_size_inches((10,10))
# ax.invert_xaxis()
# ax.invert_yaxis()
ax.imshow(cv2.rotate(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB),cv2.ROTATE_90_COUNTERCLOCKWISE),extent=[-2.69,2.5,-2.5,2.74])#[2.75,-2.69,2.74,-2.5])
for j,tortoise in enumerate(turtles):
    ax.plot(tortoise.iloc[-1][3],tortoise.iloc[-1][4],'X',color=col[j])
    # plt.axis('off')
    fig.set_alpha(0.2)
ax.legend(legend)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 from matplotlib import transforms
#       5 import os , glob , sys
# ----> 6 import moviepy ,cv2
#       7 files = glob.glob("./data/1689845489_right/*csv")
#       8 files.sort()
#
# ModuleNotFoundError: No module named 'moviepy'
